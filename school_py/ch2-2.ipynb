# %% [markdown]
# ## 2.4 變數的設值與運算的優先順序

# %% [markdown]
# ### 10.下列各小題運算完之後，變數x的值為何？

# %%
x=5; x+=2;print(x)
x=7; x*=3;print(x)
x=3; x**=4;print(x)
# Out:
# 7
# 21
# 81

# %% [markdown]
# ### 11.試以紙筆推導下面各式的計算結果，並以Python驗證您的結果是否正確：

# %%
print(6+3**2*4)  #6+3^2*4=6+9*4=42
print(15/3+4*4/2)#5+8=13
print(6>2+5)     #6>7錯
# Out:
# 42
# 13.0
# False

# %% [markdown]
# ### 12.如果在Python裡執行下面兩行敘述，您會得到不同的錯誤訊息：

# %%
print(f'{True} + not \'piggy\'')
print(f'not \'piggy\' + {True}')
#類型不一樣
# Out:
# True + not 'piggy'
# not 'piggy' + True

# %% [markdown]
# ## 2.5 型別轉換

# %% [markdown]
# ### 13.下面的敘述都會牽涉到型別的轉換，試說明它們是屬於隱式還是顯式轉換。

# %%
print(2+True)          #隱式轉換
print(6+int(17.4))     #顯示轉換
print(21+6.5)          #隱式轉換
print(str(2) + 'piggy')#顯示轉換
# Out:
# 3
# 23
# 27.5
# 2piggy

# %% [markdown]
# ### 14.試將下面表達成字串的運算式求值：

# %%
print(eval('66+18'))
print(eval('6**2+3*(7-1)'))
print(eval('int(\'2020\')'))
# Out:
# 84
# 54
# 2020

# %% [markdown]
# ## 2.6 不同進位數字的轉換

# %% [markdown]
# ### 15.試將10進位的整數1024分別轉成2進位、8進位和16進位。

# %%
print(f'2進位:{bin(1024)}',f'8進位:{oct(1024)}',f'16進位:{hex(1024)}',sep='\t')
# Out:
# 2進位:0b10000000000	8進位:0o2000	16進位:0x400

# %% [markdown]
# ### 16.試將8進位的數字0o65416分別轉成2進位、10進位和16進位。

# %%
val=int(0o65416)
print(f'2進位:{bin(val)}',f'10進位:{val}',f'16進位:{hex(val)}',sep='\t')
# Out:
# 2進位:0b110101100001110	10進位:27406	16進位:0x6b0e

# %% [markdown]
# ### 17.試將2進位的數字0b1001001分別轉成8進位、10進位和16進位。

# %%
val=int(0b1001001)
print(f'8進位:{oct(val)}',f'10進位:{val}',f'16進位:{hex(val)}',sep='\t')
# Out:
# 8進位:0o111	10進位:73	16進位:0x49

# %% [markdown]
# ## 2.7 輸出與輸入函數

# %% [markdown]
# ### 18.試利用print() 函數印出下面的字串

# %%
print('\'Holliday\'')
print('\"You may say I\'m a dreamer\"')
print('A back slash \\ sign.')
print('\'\'\'n represents a new line character\'\'\'')
# Out:
# 'Holliday'
# "You may say I'm a dreamer"
# A back slash \ sign.
# '''n represents a new line character'''

# %% [markdown]
# ### 19.設𝑎=12670, 𝑏=12.344，試利用𝑓-字串將變數𝑎與𝑏列印出如下的格式，其中符號◌代表一個空格：

# %%
𝑎=12670
𝑏=12.344
print('a={:7d}, b={:6.2f}'.format(a,b))
print('a={:+7d}, b={:06.2f}'.format(a,b))
print('a={:+7,d}, b={:06.1f}'.format(a,b))
print('a={:07,d}, b={:+6.0f}'.format(a,b))
print('a={{{:d}}}, b=\'{:4.0f}\''.format(a,b))
# Out:
# a=  12670, b= 12.34
# a= +12670, b=012.34
# a=+12,670, b=0012.3
# a=012,670, b=   +12
# a={12670}, b='  12'

# %% [markdown]
# ### 20.試從鍵盤讀入一個整數，計算這個整數的平方之後，將它列印出來。

# %%
val=int(input('輸入:'))
print(val**2)
# Out:
# 輸入:10
# 100

# %% [markdown]
# ### 21.試從鍵盤讀入一個整數，把 它轉成2進位後  ，將轉換結果列印出來

# %%
val=int(input('輸入:'))
print(bin(val))
# Out:
# 輸入:10
# 0b1010
