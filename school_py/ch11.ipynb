# %% [markdown]
# ## 第十㇐章習題

# %% [markdown]
# ## 1.1 Matplotlib繪圖的基本認識

# %% [markdown]
# ## 1.於下面各小題中，試利用add_subplot() 添加㇐個子圖到畫布中，然後繪製函數的圖形（繪出來的圖形應盡可能平滑）：

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize=(12,6))
#(a)
ax1 = fig.add_subplot(2, 2, 1)
x = np.linspace(-7, 4, 256)
y = x**4+6*x**3+7*x+3
ax1.plot(x, y)
#(b)
ax2 = fig.add_subplot(2, 2, 2)
y = 6*np.sin(x+3)*np.cos(x)
x = np.linspace(-np.pi, 2*np.pi, 256)
ax2.plot(x, y)
#(c)
ax3 = fig.add_subplot(2, 2, 3)
x = np.linspace(-3, 6, 256)
y = (x+3)/(x**2+1)
ax3.plot(x, y)
#display
plt.show()

# %% [markdown]
# ## 2.試利用subplots() 添加㇐個子圖到畫布中，然後繪製下列各函數的圖形：

# %%
fig,ax=plt.subplots(2,2,figsize=(10,10))
#(a)
x=np.linspace(-7,4,256)
y=x*4+6*x**3+7*x+3
ax[0,0].plot(x,y)
#(b)
x=np.linspace(-np.pi,np.pi)
ax[0,1].plot(x,np.sin(x**2)*np.cos(x))
#(c)
x=np.linspace(0,4*np.pi,256)
ax[1,0].plot(x,np.exp(-0.5*x)*np.sin(x))
#(d)
t=np.linspace(0,2*np.pi,256)
ax[1,1].plot(x,np.exp(-t)*np.sin(3*t+2))
plt.show()

# %% [markdown]
# ## 3.試繪出𝑓(𝑥)=sin(𝑥)/(𝑥+1) 的圖形，範圍為0≤𝑥≤4𝜋，並利用savefig() 函數儲存繪出來的圖形，檔名為myplot.png，dpi為72，背景設為不透明。

# %%
fig = plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
x=np.linspace(0,4*np.pi,256)
y=np.sin(x)/(x+1)
ax.plot(x,y)
plt.savefig('plot.png',dpi=300,transparent=False)
plt.show()

# %% [markdown]
# ## 11.2 二維圖形的修飾

# %% [markdown]
# ## 4.試將𝑓(𝑥)=sin(𝑥^2)與𝑓(𝑥)=sin^2(𝑥)繪於同㇐張圖，範圍為 0≤𝑥≤𝜋，並在繪圖區的左下角加上圖例。

# %%
fig = plt.figure(figsize=(4,3))
ax=fig.add_subplot()
x=np.linspace(0,np.pi,256)
y=np.sin(x**2)
y1=np.cos(x)**2
ax.plot(x, y, label='r=sin(x^2)')
ax.plot(x, y1, label='r=sin^2(x)')
ax.legend()
plt.show()

# %% [markdown]
# ## 5.試繪出𝑓1(𝑥)=sin(𝑥)、𝑓2(𝑥)=sin(2𝑥)、𝑓3(𝑥)=sin(3𝑥)與𝑓4(𝑥)=sin(4𝑥)的圖形，繪圖範圍請用 0≤𝑥≤2𝜋，每個子圖請用不同顏色的線條，並將它們排成如下 2×2  的子圖：

# %%
fig,ax=plt.subplots(2,2,figsize=(12,6))
#(a)
x=np.linspace(0,2*np.pi,256)
y=np.sin(x)
ax[0,0].plot(x,y,'r',label='y=sin(x)')
ax[0,0].legend(loc='upper right')
#(b)
y=np.sin(2*x)
ax[0,1].plot(x,y,'g',label='y=sin(2*x)')
ax[0,1].legend(loc='upper right')
#(c)
y=np.sin(3*x)
ax[1,0].plot(x,y,'b',label='y=sin(3*x)')
ax[1,0].legend(loc='upper right')
#(d)
y=np.sin(4*x)
ax[1,1].plot(x,y,'y',label='y=sin(4*x)')
ax[1,1].legend(loc='upper right')
plt.show()

# %% [markdown]
# ## 6.試分別利用紅綠藍三種顏色繪出𝑓1(𝑥)=sin(𝑥)、𝑓2(𝑥)=cos(2𝑥)與𝑓3(𝑥)=sin(𝑥)+cos(2𝑥)的圖形，繪圖範圍0≤𝑥≤2𝜋，畫布大小設為 figsize=(5,10)，並將它們排成如下3×1 的圖形：

# %%
fig,ax = plt.subplots(3,1,figsize=(5,10))
x=np.linspace(0,2*np.pi,256)
y=np.sin(x)
ax[0].plot(x,y)
y=np.cos(2*x)
ax[1].plot(x,y)
y=np.sin(x)+np.cos(2*x)
ax[2].plot(x,y)
plt.show()

# %% [markdown]
# ## 7.試繪出$$y = x \cdot \log_{10}(3x) \cdot \sin(\sqrt{x})$$，1≤𝑥≤1000的圖形，其中𝑥軸為對數坐標，並加上網格線。

# %%
fig=plt.figure(figsize=(4,3))
x=np.linspace(1,1000,256)
y=x*np.log10(3*x)*np.sin(np.sqrt(x))
plt.plot(x,y,linewidth=2)
plt.grid()
plt.show()

# %% [markdown]
# ## 8.試繪出y=x^x，0≤𝑥≤16的圖形，其中y軸為對數坐標，並加上網格線。

# %%
fig=plt.figure(figsize=(4,3))
x=np.linspace(0,16,256)
y=x**x
plt.plot(x,y,linewidth=2)
plt.grid()
plt.show()

# %% [markdown]
# ## 9.試繪出$$y = \frac{x \cdot e^x}{x^2 + 1}$$.，1≤𝑥≤100 的圖形，其中x與y軸均為對數坐標。

# %%
fig=plt.figure(figsize=(4,3))
x=np.linspace(1,100,256)
y=(x*np.exp(x))/(x**2+1)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 10.設𝑓(𝑛)為小於等於𝑛之質數的個數（𝑛為整數），例如2, 3, 5, 7,11, 13, 17, 19皆為質數，因此𝑓(2)=1，𝑓(7)=4，𝑓(19)=𝑓(20)=8。試繪出𝑓(𝑛)，2≤𝑛≤100的圖形。在此題中，因為𝑛為整數時，𝑓(𝑛)才有定義，所以點和點之間不要以線條連接。

# %%
import numpy as np
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True
x = np.arange(2, 101)
y = [sum(is_prime(i) for i in range(2, n+1)) for n in x]
plt.scatter(x, y)#散佈圖
plt.xlabel('n')
plt.ylabel('f(n)')
plt.title('Number of primes less than or equal to n')
plt.show()

# %% [markdown]
# ## 11.3 填滿繪圖與極坐標繪圖

# %% [markdown]
# ## 11.試利用plot() 函數繪製𝑓(𝑥)=cos(3𝑥), 0≤𝑥≤𝜋，繪圖點數取32個，線條為紅色的虛線，資料點以大小為8的小圓來呈現，並以黃色填滿。繪圖區的標題為  'My plot'，字體大小為18，並加上網格線。

# %%
x = np.linspace(0, np.pi, 32)
y = np.cos(3 * x)
plt.plot(x, y, 'ro-', markersize=8, markerfacecolor='yellow', linestyle='dashed', color='red')
plt.title('My plot', fontsize=18)
plt.grid(True)
plt.show()
# Out:
# C:\Users\chen1\AppData\Local\Temp\ipykernel_17460\1764082792.py:3: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "ro-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro-', markersize=8, markerfacecolor='yellow', linestyle='dashed', color='red')
# C:\Users\chen1\AppData\Local\Temp\ipykernel_17460\1764082792.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, 'ro-', markersize=8, markerfacecolor='yellow', linestyle='dashed', color='red')

# %% [markdown]
# ## 12.試繪出𝑟=sin(6𝑥)的極坐標圖， 0≤𝑥≤2𝜋，坐標軸𝑟的刻度為 −1,−0.5,0,0.5,1，資料點數取120點。

# %%
x = np.linspace(0, 2 * np.pi, 120)
r = np.sin(6 * x)
plt.polar(x, r)
plt.yticks([-1, -0.5, 0, 0.5, 1])
plt.show()

# %% [markdown]
# ## 13.試將𝑟=sin(3𝑥)與𝑟=cos(sin(6𝑥))，0≤𝑥≤2𝜋的圖形繪於同㇐張極坐標圖上，坐標軸𝑟的刻度為 −1,0,1，資料點數取120。

# %%
x = np.linspace(0, 2 * np.pi, 120)
r1 = np.sin(3 * x)
r2 = np.cos(np.sin(6 * x))
plt.polar(x, r1, label='r=sin(3x)')
plt.polar(x, r2, label='r=cos(sin(6x))')
plt.yticks([-1, 0, 1])
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## 11.4 統計繪圖

# %% [markdown]
# ## 14.設某個地區春天的降雨量為138公厘，夏天為187公厘，秋天為92公厘，冬天為63公厘。試以圓餅圖表示每㇐季降雨量所佔的百分比。

# %%
labels=['summer','spring','autumn','winter']
sizes=[187,138,92,63]
colors=['yellowgreen','gold','lightskyblue','lightcoral']
explode=(0,0,0,0)
fig,ax=plt.subplots()
ax.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=90)
ax.axis('equal')
plt.show()

# %% [markdown]
# ## 15.試產生3600個平均值為1，標準差為5的常態分佈亂數，並以20個組界的直方圖來繪製這筆資料，並以組界寬度的 80% 做為直方圖中，每個長條的寬度。

# %%
s=np.random.normal(1,5,3600)# mu sigma size
coumt,bins,ignored=plt.hist(s,20,density=True,alpha=0.5,rwidth=0.8)
plt.show()

# %% [markdown]
# ## 16.設𝑥和𝑦均是由1200個平均值為170，標準差為16的常態分佈亂數所組成的向量，試分別以plot() 和scatter() 函數繪出資料點(𝑥,𝑦)的分佈圖於同㇐張畫布上，圖像左右排列，𝑥-𝑦坐標軸的比為 1:1。

# %%
mu, sigma = 170, 16
x = np.random.normal(mu, sigma, 1200)
y = np.random.normal(mu, sigma, 1200)
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
# plot()方法
axs[0].plot(x, y, 'o')
axs[0].set_title('plot()')
axs[0].axis('equal')
# scatter()方法
axs[1].scatter(x, y)
axs[1].set_title('scatter()')
axs[1].axis('equal')
plt.show()

# %% [markdown]
# ## 17.試以長條圖繪製執骰子10000次，每㇐個點數出現的次數。

# %%
import random
random.seed(10)
num=[random.randint(1,6) for _ in range(10000)]
x=[i for i in range(1,7)]
y=[num.count(i) for i in x]
fig,ax=plt.subplots()
ax.bar(x,y,color='green')
plt.show()

# %% [markdown]
# ## 11.5等高線圖與三維繪圖

# %% [markdown]
# ## 18.試繪出下列各函數的二維、三維等高線圖與3維的曲面圖，並將它們顯示在㇐個 1×3 的子圖中。二維的等高線需顯示等高線的值，figsize參數的值設為  (10, 3)。

# %% [markdown]
# ### (a)sin(𝑥) sin (𝑦),0≤𝑥≤2𝜋,0≤𝑦≤2𝜋，等高線為 –0.7,−0.3,0,0.3,0.7。

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(10,3))
x=np.linspace(0,2*np.pi,256)
y=np.linspace(0,2*np.pi,256)
l=[-0.7,-0.3,0,0.3,0.7]
x,y=np.meshgrid(x,y)
z=np.sin(x)*np.sin(y)
# 2D Contour plot
ax1=fig.add_subplot(131)
count=ax1.contour(x,y,z,levels=l)
ax1.clabel(count,inline=True,fontsize=10)
ax1.set_title('2D Contour plot')
# 3D Contour plot
ax2=fig.add_subplot(132,projection='3d')
ax2.contour(x,y,z,levels=l)
ax2.set_title('3D Contour plot')
# 3D Surface plot
ax3=fig.add_subplot(133,projection='3d')
ax3.plot_surface(x,y,z,cmap='viridis')
ax3.set_title('3D Surface plot')
plt.show()

# %% [markdown]
# ### (b) $$\frac{1}{\sqrt{x^2+y^2+1}}$$,−𝜋≤𝑥≤𝜋,−𝜋≤𝑦≤𝜋，5條等高線。

# %%
fig=plt.figure(figsize=(10,3))
x=np.linspace(-np.pi,np.pi,256)
y=np.linspace(-np.pi,np.pi,256)
x,y=np.meshgrid(x,y)
z=1/np.sqrt(x**2+y**2+1)
# 2D Contour plot
ax1=fig.add_subplot(131)
count=ax1.contour(x,y,z,levels=5)
ax1.clabel(count,inline=True,fontsize=10)
ax1.set_title('2D Contour plot')
# 3D Contour plot
ax2=fig.add_subplot(132,projection='3d')
ax2.contour(x,y,z,levels=5)
ax2.set_title('3D Contour plot')
# 3D Surface plot
ax3=fig.add_subplot(133,projection='3d')
ax3.plot_surface(x,y,z,cmap='viridis')
ax3.set_title('3D Surface plot')
plt.show()

# %% [markdown]
# ### (c)$$\frac{y}{{(x^2+y^2+1)}^{4/5}}$$,  −4≤𝑥≤4,−4≤𝑦≤4，6條等高線。

# %%
fig=plt.figure(figsize=(10,3))
x=np.linspace(-4,4,256)
y=np.linspace(-4,4,256)
x,y=np.meshgrid(x,y)
z=(y/(x**2+y**2+1))**(4/5)
# 2D Contour plot
ax1=fig.add_subplot(131)
count=ax1.contour(x,y,z,levels=6)
ax1.clabel(count,inline=True,fontsize=10)
ax1.set_title('2D Contour plot')
# 3D Contour plot
ax2=fig.add_subplot(132,projection='3d')
ax2.contour(x,y,z,levels=6)
ax2.set_title('3D Contour plot')
# 3D Surface plot
ax3=fig.add_subplot(133,projection='3d')
ax3.plot_surface(x,y,z,cmap='viridis')
ax3.set_title('3D Surface plot')
plt.show()
# Out:
# C:\Users\chen1\AppData\Local\Temp\ipykernel_17460\1800584230.py:5: RuntimeWarning: invalid value encountered in power
#   z=(y/(x**2+y**2+1))**(4/5)

# %% [markdown]
# ### (d)$$(x^2+y)e^{-x^2-y^2}$$, −3≤𝑥≤3,−3≤𝑦≤3，6條等高線。

# %%
fig=plt.figure(figsize=(10,3))
x=np.linspace(-3,3,256)
y=np.linspace(-3,3,256)
x,y=np.meshgrid(x,y)
z=(x**2+y)*np.exp(-x**2-y**2)
# 2D Contour plot
ax1=fig.add_subplot(131)
count=ax1.contour(x,y,z,levels=6)
ax1.clabel(count,inline=True,fontsize=10)
ax1.set_title('2D Contour plot')
# 3D Contour plot
ax2=fig.add_subplot(132,projection='3d')
ax2.contour(x,y,z,levels=6)
ax2.set_title('3D Contour plot')
# 3D Surface plot
ax3=fig.add_subplot(133,projection='3d')
ax3.plot_surface(x,y,z,cmap='viridis')
ax3.set_title('3D Surface plot')
plt.show()

# %% [markdown]
# ## 19.設𝑥和𝑦為平均分佈的浮點數亂數，0≤𝑥≤6,0≤𝑦≤6，而𝑧為平均值為5，標準差為8的常態分佈亂數。試利用scatter() 繪出1000個這樣的亂數，並使用jet色表，顏色依𝑧軸的值來上色。

# %%
x = np.random.uniform(0, 6, 1000)
y = np.random.uniform(0, 6, 1000)
z = np.random.normal(5, 8, 1000)
plt.scatter(x, y, c=z, cmap='jet')
plt.colorbar(label='z value')
plt.show()

# %% [markdown]
# ## 20.試繪出$$(x+y)e^{-x^2-y^2}$$, −2≤𝑥≤2,−2≤𝑦≤2的三維曲面圖，並設定仰角為40度，水平角為160度。

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
x, y = np.meshgrid(x, y)
z = (x + y) * np.exp(-x**2 - y**2)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')
ax.view_init(40, 160)
plt.show()

# %% [markdown]
# ## 21.試分別繪出$$\log(1+x^2+y^2)$$的三維等高線圖（等高線為 0.1、0.3 與 0.5）與三維曲面圖（色表為jet）於同㇐張畫布上，圖形左右排列，−2≤𝑥≤2，−2≤𝑦≤2。

# %%
fig = plt.figure(figsize=(12, 6))
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
x, y = np.meshgrid(x, y)
z = np.log(1 + x**2 + y**2)
# 3D Contour plot
ax1 = fig.add_subplot(121, projection='3d')
ax1.contour3D(x, y, z, levels=[0.1, 0.3, 0.5], cmap='jet')
# 3D Surface plot
ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_surface(x, y, z, cmap='jet')
plt.show()

# %% [markdown]
# ## 11.6動畫的製作

# %% [markdown]
# ## 22.試製作㇐個紅球（大小為10，markersize=10）在二維函數𝑓(𝑥)=tan(sin(𝑥))−sin(tan(𝑥))上方移動的動畫，0≤𝑥≤𝜋，幀數為240，每幀播放的間隔為0.05秒。下圖為其中的三幀動畫：

# %%
# import matplotlib.animation as animation
# fig, ax = plt.subplots()
# x = np.linspace(0, np.pi, 240)
# f = np.tan(np.sin(x)) - np.sin(np.tan(x))
# ax.plot(x, f)
# ball, = ax.plot([], [], 'ro', markersize=10)
# def update(frame):
#     ball.set_data(x[frame], f[frame])
#     return ball,
# ani = animation.FuncAnimation(fig, update, frames=range(240), interval=50, blit=True)
# plt.show()

# %% [markdown]
# ## 23.試製作㇐個紅球（大小為10，markersize=10）在極坐標函數𝑟=sin(6𝑡),0≤𝑡≤2𝜋上方移動的軌跡，移動時𝑟=sin(6𝑡)的圖形會㇐起繪出。幀數取256，每幀播放間隔為0.05秒。下圖為其中三幀動畫（提示：可利用set_data(𝑡,𝑟) 來設定𝑡和𝑟=sin(6𝑡)的坐標）：

# %%
# fig = plt.figure()
# t = np.linspace(0, 2*np.pi, 256)
# r = np.sin(6*t)
# ax = fig.add_subplot(111, polar=True)
# ax.plot(t, r)
# ball, = ax.plot([], [], 'ro', markersize=10)
# def update(frame):
#     ball.set_data(t[frame], r[frame])
#     return ball,
# ani = animation.FuncAnimation(fig, update, frames=range(256), interval=50, blit=True)
# plt.show()
